# %%
# Exercise 1: Print name, student number, and email address with a line space
print("Exercise 1: Name, Student Number, and Email ID")
print("")

print("Vysakh M")
print("54")
print("vysakh.m7@gmail.com")
print("")
print("")


# Exercise 2: Print name, student number, and email address using escape sequences with a line space
print("Exercise 2: Name, Student Number, and Email ID with Escape Sequences")
print("")

print("Name: Vysakh M\nStudent Number: 54\nEmail: vysakh.m7@gmail.com")
print("")
print("")

# Exercise 3: Add, subtract, multiply, and divide two numbers
print("Exercise 3: Basic Arithmetic Operations")
print("")

num1 = 14
num2 = 7
print(f"{num1} + {num2} = {num1 + num2}")
print(f"{num1} * {num2} = {num1 * num2}")
print(f"{num1} - {num2} = {num1 - num2}")
print(f"{num1} / {num2} = {num1 / num2}\n\n")

# Exercise 4: Display the numbers from 1 to 5 as steps
print("Exercise 4: Display Numbers from 1 to 7")
print("")

for i in range(1, 7):
    print(i)
print("\n")

# Exercise 5: Output a sentence with quotation marks and line breaks
print("Exercise 5: Sentence with Quotation Marks and Line Breaks")
print("")

print("\"SDK\" stands for \"Software Development Kit\", whereas \"IDE\" stands for \"Integrated Development Environment\".\n\n")

# Exercise 6: Practice and check the output
print("Exercise 6: Practice with Escape Sequences")
print("")

print("python is an \"awesome\" language.")
print("python\n\t2023")
print('I\'m from Entri.\b')
print("\65")
print("\x65")
print("Entri", "2023", sep="\n")
print("Entri", "2023", sep="\b")
print("Entri", "2023", sep="*", end="\b\b\b\b\n\n")

# Exercise 7: Define variables, print their types, and sum the variables
print("Exercise 7: Variables and Their Sum")
print("")

num = 23
textnum = "57"
decimal = 98.3
print(f"Type of num: {type(num)}")
print(f"Type of textnum: {type(textnum)}")
print(f"Type of decimal: {type(decimal)}")

# Sum of variables
sum_variables = num + int(textnum) + decimal
print(f"Sum of variables: {sum_variables}")
print(f"Datatype of sum: {type(sum_variables)}\n\n")

# Exercise 8: Calculate the number of minutes in a year
print("Exercise 8: Minutes in a Year")
print("")

days_in_year = 365
hours_in_day = 24
minutes_in_hour = 60
total_minutes_in_year = days_in_year * hours_in_day * minutes_in_hour
print(f"Total minutes in a year: {total_minutes_in_year}\n\n")

# Exercise 9: Ask for user input and print a greeting
print("Exercise 9: Greeting with User Input")
print("")

name = input("Please enter your name: ")
print(f"Hi {name}, welcome to Python programming :)\n\n")

# Exercise 10: Convert pounds to dollars
print("Exercise 10: Convert Pounds to Dollars")
print("")

pounds = float(input("Please enter amount in pounds: "))
dollars = pounds * 1.39  # Example conversion rate, adjust as needed
print(f"£{pounds} are ${dollars:.2f}")
# Out:
# Exercise 1: Name, Student Number, and Email ID
#
# Vysakh M
# 54
# vysakh.m7@gmail.com
#
#
# Exercise 2: Name, Student Number, and Email ID with Escape Sequences
#
# Name: Vysakh M
# Student Number: 54
# Email: vysakh.m7@gmail.com
#
#
# Exercise 3: Basic Arithmetic Operations
#
# 14 + 7 = 21
# 14 * 7 = 98
# 14 - 7 = 7
# 14 / 7 = 2.0
#
#
# Exercise 4: Display Numbers from 1 to 7
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# Exercise 5: Sentence with Quotation Marks and Line Breaks
#
# "SDK" stands for "Software Development Kit", whereas "IDE" stands for "Integrated Development Environment".
#
#
# Exercise 6: Practice with Escape Sequences
#
# python is an "awesome" language.
# python
# 	2023
# I'm from Entri
# 5
# e
# Entri
# 2023
# Entr2023
# Entri*20
#
# Exercise 7: Variables and Their Sum
#
# Type of num: <class 'int'>
# Type of textnum: <class 'str'>
# Type of decimal: <class 'float'>
# Sum of variables: 178.3
# Datatype of sum: <class 'float'>
#
#
# Exercise 8: Minutes in a Year
#
# ...
